# %%
#import libraries
import warnings
import yfinance as yf
import os
from datetime import datetime, timedelta
import json
import pandas as pd

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Loading and Preparation
#
# In this analysis we choose tho use the SP500 sectors

# %%
universe_name = "selection2"
interval = '1d'  # daily frequency
to_date = datetime.now()  # today pd.to_datetime("2015-12-31") #
from_date = pd.to_datetime("2012-01-01") # to_date - timedelta(days=13*365)  # past ten years pd.to_datetime("2005-12-31") #

universe_symbols = ['SPY','GLD','SLV','DBA','DBB','CPER','CANE','TLH','ISTB','EMB','ILF','INDA','MCHI','IEV','EWJ','EWA','USO','BWX','CBON','VGSH']
universe_asset_class = ['Equity','Commodities','Commodities','Commodities','Commodities','Commodities','Commodities','Bonds','Bonds','Bonds','Equity','Equity','Equity','Equity','Equity','Equity','Commodities','Bonds','Bonds','Bonds']

# %%
universe_name = "selection3"
interval = '1d'  # daily frequency
to_date = datetime.now()  # today pd.to_datetime("2015-12-31") #
from_date = pd.to_datetime("2012-10-24") # to_date - timedelta(days=13*365)  # past ten years pd.to_datetime("2005-12-31") #

selection_df = pd.read_csv('selection3.csv',index_col=0,delimiter=';',header=0)
universe_symbols = selection_df.index.tolist()
universe_asset_class = selection_df['asset_class'].tolist()
try:
    universe_tracker = selection_df['Tracker'].tolist()
except Exception as e:
    print(f"Error occurred while reading 'Tracker' column: {e}")
    universe_tracker = ['']*len(universe_symbols)

# %%
#download universe from yahoo
print(f"Number of {universe_name} symbols loaded: {len(universe_symbols)}")
start_date = from_date.strftime('%Y-%m-%d')
end_date = to_date.strftime('%Y-%m-%d')

print(f"Downloading data from {start_date} to {end_date}...")

universe_data = yf.download(
    tickers=universe_symbols,
    start=start_date,
    end=end_date,
    interval=interval,
    group_by='ticker',
    auto_adjust=False,
    threads=True,
    progress=False
)
universe_data= pd.DataFrame(universe_data)
# Map Yahoo Finance column names to project conventions for multi-level columns
if isinstance(universe_data.columns, pd.MultiIndex):
    universe_data = universe_data.rename(columns={
        'Open': 'open',
        'High': 'high',
        'Low': 'low',
        'Close': 'close',
        'Adj Close': 'adjusted',
        'Volume': 'volume'
    }, level=1)
else:
    universe_data = universe_data.rename(columns={
        'Open': 'open',
        'High': 'high',
        'Low': 'low',
        'Close': 'close',
        'Adj Close': 'adjusted',
        'Volume': 'volume'
    })
#universe_data = universe_data.xs('Adj Close', axis=1, level=1)[universe_symbols].dropna()

if isinstance(universe_data.columns, pd.MultiIndex):
    asset_names = universe_data.columns.get_level_values(0).unique()
    print(f"Downloaded data for {len(asset_names)} assets")
else:
    print(f"Downloaded data for {len(universe_data.columns)} assets")

universe_info = {}
for symbol in universe_symbols:
    try:
        ticker = yf.Ticker(symbol)
        universe_info[symbol] = ticker.info
    except Exception as e:
        print(f"Error fetching data for {symbol}: {e}")
universe_info = pd.DataFrame(universe_info).T

universe_folder_path = os.path.join(os.getcwd(),'data', universe_name)

if not os.path.exists(universe_folder_path):
    os.makedirs(universe_folder_path)

try:
    universe_data.to_csv(os.path.join(universe_folder_path, 'universe_data.csv'))
    universe_info.to_csv(os.path.join(universe_folder_path, 'universe_info.csv'))
    universe_settings = {
        'universe_name': universe_name,
        'from_date': start_date,
        'to_date': end_date,
        'interval': interval,
        'universe_symbols': universe_symbols,
        'universe_asset_class': universe_asset_class
    }
    with open(os.path.join(universe_folder_path, 'universe_settings.json'), 'w') as f:
        json.dump(universe_settings, f, indent=4)
    print(f"Universe data and info saved in folder: {universe_folder_path}")
except Exception as e:
    print(f"Error saving universe data: {e}")
# Out:
# Number of selection3 symbols loaded: 53
# Downloading data from 2012-10-24 to 2025-11-03...
# Downloaded data for 53 assets
# Universe data and info saved in folder: c:\my-git\DataScience-novaIMS\APPM-individual\data\selection3

# %%
#download and save info data
close_data = universe_data.xs('adjusted', axis=1, level=1) if isinstance(universe_data.columns, pd.MultiIndex) else universe_data['adjusted']
info_data = universe_info[['shortName','longName', 'fundFamily', 'fundInceptionDate']]
summary_df = pd.DataFrame(columns=['Symbol', 'Name', 'Earliest', 'Latest','fundFamily', 'fundInceptionDate'])
for col in close_data.columns:
    col_data = close_data[col].dropna()
    summary_df = pd.concat([summary_df, pd.DataFrame({
        'Symbol': [col],
        'Name': [info_data.loc[col, 'shortName']],
        'Earliest': [col_data.index.min().date()],
        'Latest': [col_data.index.max().date()],
        'fundFamily': [info_data.loc[col, 'fundFamily']],
        'fundInceptionDate': [info_data.loc[col, 'fundInceptionDate']]
    })], ignore_index=True)

summary_df['fundInceptionDate'] = pd.to_datetime(summary_df['fundInceptionDate'], unit='s').dt.date
display(summary_df.sort_values(by='Earliest',ascending=False))
summary_df.to_csv(os.path.join(universe_folder_path, 'universe_summary.csv'), index=False, sep=';')
# Out:
#    Symbol                             Name    Earliest      Latest  \
# 0     EWT  iShares Inc iShares MSCI Taiwan  2012-10-24  2025-10-31
# 27    AIA              iShares Asia 50 ETF  2012-10-24  2025-10-31
# 29    EWG  iShares MSCI Germany Index Fund  2012-10-24  2025-10-31
# 30   CORN           Teucrium Corn Fund ETV  2012-10-24  2025-10-31
# 31    EWQ   iShares MSCI France Index Fund  2012-10-24  2025-10-31
# 32    UCO  ProShares Ultra Bloomberg Crude  2012-10-24  2025-10-31
# 33    BIL  State Street SPDR Bloomberg 1-3  2012-10-24  2025-10-31
# 34    USO           United States Oil Fund  2012-10-24  2025-10-31
# 35   SOYB        Teucrium Soybean Fund ETV  2012-10-24  2025-10-31
# 36    EWU                     iShares MSCI  2012-10-24  2025-10-31
# 37   VGSH  Vanguard Short-Term Treasury ET  2012-10-24  2025-10-31
# 38    ILF     iShares Latin America 40 ETF  2012-10-24  2025-10-31
# 39    EWA  iShares MSCI Australia Index Fu  2012-10-24  2025-10-31
# 40   GREK         Global X MSCI Greece ETF  2012-10-24  2025-10-31
# 41    BWX  SPDR Bloomberg International Tr  2012-10-24  2025-10-31
# 42    TLH  iShares 10-20 Year Treasury Bon  2012-10-24  2025-10-31
# 43    SPY                     SPDR S&P 500  2012-10-24  2025-10-31
# 44    UGA   United States Gasoline Fund LP  2012-10-24  2025-10-31
# 45    SLV             iShares Silver Trust  2012-10-24  2025-10-31
# 46    QQQ      Invesco QQQ Trust, Series 1  2012-10-24  2025-10-31
# 47    TUR          iShares MSCI Turkey ETF  2012-10-24  2025-10-31
# 48    VGK        Vanguard FTSEEuropean ETF  2012-10-24  2025-10-31
# 49    FEZ        SPDR DJ Euro STOXX 50 Etf  2012-10-24  2025-10-31
# 50   URTH  iShares, Inc. iShares MSCI Worl  2012-10-24  2025-10-31
# 51   ARGT      Global X MSCI Argentina ETF  2012-10-24  2025-10-31
# 28   ISTB  iShares Core 1-5 Year USD Bond   2012-10-24  2025-10-31
# 26   EPOL  iShares Trust iShares MSCI Pola  2012-10-24  2025-10-31
# 1    CPER  United States Copper Index Fund  2012-10-24  2025-10-31
# 25    DBE           Invesco DB Energy Fund  2012-10-24  2025-10-31
# 2     EWW  iShares Inc iShares MSCI Mexico  2012-10-24  2025-10-31
# 3     EWD  iShares Inc iShares MSCI Sweden  2012-10-24  2025-10-31
# 4    WEAT          Teucrium Wheat Fund ETV  2012-10-24  2025-10-31
# 5    MCHI           iShares MSCI China ETF  2012-10-24  2025-10-31
# 6    GOVI  Invesco Equal Weight 0-30 Year   2012-10-24  2025-10-31
# 7     UNG  United States Natural Gas Fund   2012-10-24  2025-10-31
# 8     EWZ  iShares Inc iShares MSCI Brazil  2012-10-24  2025-10-31
# 9     EWJ    iShares MSCI Japan Index Fund  2012-10-24  2025-10-31
# 10   CANE          Teucrium Sugar Fund ETV  2012-10-24  2025-10-31
# 11    TLT  iShares 20+ Year Treasury Bond   2012-10-24  2025-10-31
# 12    ECH  iShares Inc. iShares MSCI Chile  2012-10-24  2025-10-31
# 13    GLD                  SPDR Gold Trust  2012-10-24  2025-10-31
# 14    EEM  iShares MSCI Emerging Index Fun  2012-10-24  2025-10-31
# 15    EZU        iShares MSCI Eurozone ETF  2012-10-24  2025-10-31
# 16    EWY  iShares Inc iShares MSCI South   2012-10-24  2025-10-31
# 17    EMB  iShares J.P. Morgan USD Emergin  2012-10-24  2025-10-31
# 18    EWN  iShares MSCI Netherlands Index   2012-10-24  2025-10-31
# 19    DBA      Invesco DB Agriculture Fund  2012-10-24  2025-10-31
# 20    IEF  iShares 7-10 Year Treasury Bond  2012-10-24  2025-10-31
# 21   INDA           Ishares MSCI India ETF  2012-10-24  2025-10-31
# 22    EWI  iShares Inc iShares MSCI Italy   2012-10-24  2025-10-31
# 23    IEV               iShares Europe ETF  2012-10-24  2025-10-31
# 24    DBB      Invesco DB Base Metals Fund  2012-10-24  2025-10-31
# 52    EWL  iShares Inc iShares MSCI Switze  2012-10-24  2025-10-31
#
#                                  fundFamily fundInceptionDate
# 0                                   iShares        2000-06-20
# 27                                  iShares        2007-11-13
# 29                                  iShares        1996-03-12
# 30                                 Teucrium        2010-06-09
# 31                                  iShares        1996-03-12
# 32                                ProShares        2008-11-24
# 33  SPDR State Street Investment Management        2007-05-25
# 34                         USCF Investments        2006-04-10
# 35                                 Teucrium        2011-09-16
# 36                                  iShares        1996-03-12
# 37                                 Vanguard        2009-11-19
# 38                                  iShares        2001-10-25
# 39                                  iShares        1996-03-12
# 40                           Global X Funds        2011-12-07
# 41  SPDR State Street Investment Management        2007-10-02
# 42                                  iShares        2007-01-05
# 43  SPDR State Street Investment Management        1993-01-22
# 44                         USCF Investments        2008-02-26
# 45                                  iShares        2006-04-21
# 46                                  Invesco        1999-03-10
# 47                                  iShares        2008-03-26
# 48                                 Vanguard        2005-03-04
# 49  SPDR State Street Investment Management        2002-10-15
# 50                                  iShares        2012-01-10
# 51                           Global X Funds        2011-03-02
# 28                                  iShares        2012-10-18
# 26                                  iShares        2010-05-25
# 1                          USCF Investments        2011-11-14
# 25                                  Invesco        2007-01-05
# 2                                   iShares        1996-03-12
# 3                                   iShares        1996-03-12
# 4                                  Teucrium        2011-09-16
# 5                                   iShares        2011-03-29
# 6                                   Invesco        2007-10-11
# 7                          USCF Investments        2007-04-18
# 8                                   iShares        2000-07-10
# 9                                   iShares        1996-03-12
# 10                                 Teucrium        2011-09-16
# 11                                  iShares        2002-07-22
# 12                                  iShares        2007-11-12
# 13  SPDR State Street Investment Management        2004-11-18
# 14                                  iShares        2003-04-07
# 15                                  iShares        2000-07-25
# 16                                  iShares        2000-05-09
# 17                                  iShares        2007-12-17
# 18                                  iShares        1996-03-12
# 19                                  Invesco        2007-01-05
# 20                                  iShares        2002-07-22
# 21                                  iShares        2012-02-02
# 22                                  iShares        1996-03-12
# 23                                  iShares        2000-07-25
# 24                                  Invesco        2007-01-05
# 52                                  iShares        1996-03-12
